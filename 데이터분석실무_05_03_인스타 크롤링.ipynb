# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup

import time
import pandas as pd
import numpy as np

# %%
ser = Service('C:/Users/jhjh3/class/datasalon-master/02_data_class/chromedriver/chromedriver.exe')
driver = webdriver.Chrome(service = ser)

# %%
url = 'https://www.instagram.com/'
driver.get(url)

# %%
def insta_search(word):
    url = 'https://www.instagram.com/explore/tags/'+ word
#    url = 'https://www.instagram.com/explore/tags/{}/'.format(word)
    return(url)

# %%
word = '제주도맛집'
url = insta_search(word)
url
# Out:
# 'https://www.instagram.com/explore/tags/제주도맛집'

# %%
from selenium.webdriver.common.by import By

def select_first(driver):
    # first = driver.find_element_by_css_selector('div._9AhHO')
    first = driver.find_element(By.CSS_SELECTOR, 'div._9AhH0')
    first.click()
    time.sleep(3)
                 
select_first(driver)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
import unicodedata
content = soup.select('div.C4VMK > span')[0].text
content = unicodedata.normalize('NFC', content)

content
# Out:
# '.❤서귀포 "제주섬나무"❤유부초밥들이 너무 이뿌게 날기다리구있어..맛좋은 유부초밥들이 다양한 종류가😍😍요기요기 있다구 그리고 우동국물한입에유부초밥한입 먹으면 그..맛 절대 잊을수없다😭 @같이 달려가서 음식들 부술친구소환!@✔매장 전화번호 : 064-738-3512✔인스타그램 아이디 : @jeju_sumnamu✔주소 : 제주도 서귀포시 김정문화로 47 B103호#제주맛집 #제주도맛집 #제주공항근처맛집 #제주시맛집 #애월맛집 #중문맛집 #제주공항맛집 #서귀포맛집 #산방산맛집 #신제주맛집 #제주시청맛집 #제주애월맛집 #월정리맛집 #제주여행 #제주핫플'

# %%
import re

tags = re.findall(r'#[^\s#,\\]+', content)
tags
# Out:
# ['#제주맛집',
#  '#제주도맛집',
#  '#제주공항근처맛집',
#  '#제주시맛집',
#  '#애월맛집',
#  '#중문맛집',
#  '#제주공항맛집',
#  '#서귀포맛집',
#  '#산방산맛집',
#  '#신제주맛집',
#  '#제주시청맛집',
#  '#제주애월맛집',
#  '#월정리맛집',
#  '#제주여행',
#  '#제주핫플']

# %%
date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10]
date
# Out:
# '2022-01-24'

# %%
like = soup.select('a.zV_Nj > span')[0].text
like
# Out:
# '1,096'

# %%
place = soup.select('a.O4GlU')
# place = unicodedata.normalize('NFC', place)
place
# Out:
# []

# %%
def get_content(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        content = soup.select('div.C4VMK > span')[0].text
        content = unicodedata.normalize('NFC', content)
    except:
        content = ''
       
    try:
        tags = re.findall(r'#[^\s#,\\]+', content)
    except:
        tags = ''
        
    date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10]
    
    try:
        like = soup.select('div.Nm9Fw > a > span')[0].text
    except:
        like = 0
        
    try:
        place = soup.select('a.O4GlU')[0].text
    except:
        place=''
        
    data = [content, date, like, place, tags]
    
    return(data)

get_content(driver)
# Out:
# ['.❤서귀포 "제주섬나무"❤유부초밥들이 너무 이뿌게 날기다리구있어..맛좋은 유부초밥들이 다양한 종류가😍😍요기요기 있다구 그리고 우동국물한입에유부초밥한입 먹으면 그..맛 절대 잊을수없다😭 @같이 달려가서 음식들 부술친구소환!@✔매장 전화번호 : 064-738-3512✔인스타그램 아이디 : @jeju_sumnamu✔주소 : 제주도 서귀포시 김정문화로 47 B103호#제주맛집 #제주도맛집 #제주공항근처맛집 #제주시맛집 #애월맛집 #중문맛집 #제주공항맛집 #서귀포맛집 #산방산맛집 #신제주맛집 #제주시청맛집 #제주애월맛집 #월정리맛집 #제주여행 #제주핫플',
#  '2022-01-24',
#  '1,096',
#  '',
#  ['#제주맛집',
#   '#제주도맛집',
#   '#제주공항근처맛집',
#   '#제주시맛집',
#   '#애월맛집',
#   '#중문맛집',
#   '#제주공항맛집',
#   '#서귀포맛집',
#   '#산방산맛집',
#   '#신제주맛집',
#   '#제주시청맛집',
#   '#제주애월맛집',
#   '#월정리맛집',
#   '#제주여행',
#   '#제주핫플']]

# %%
mylist = get_content(driver)
mylist
# Out:
# ['.❤서귀포 "제주섬나무"❤유부초밥들이 너무 이뿌게 날기다리구있어..맛좋은 유부초밥들이 다양한 종류가😍😍요기요기 있다구 그리고 우동국물한입에유부초밥한입 먹으면 그..맛 절대 잊을수없다😭 @같이 달려가서 음식들 부술친구소환!@✔매장 전화번호 : 064-738-3512✔인스타그램 아이디 : @jeju_sumnamu✔주소 : 제주도 서귀포시 김정문화로 47 B103호#제주맛집 #제주도맛집 #제주공항근처맛집 #제주시맛집 #애월맛집 #중문맛집 #제주공항맛집 #서귀포맛집 #산방산맛집 #신제주맛집 #제주시청맛집 #제주애월맛집 #월정리맛집 #제주여행 #제주핫플',
#  '2022-01-24',
#  '1,096',
#  '',
#  ['#제주맛집',
#   '#제주도맛집',
#   '#제주공항근처맛집',
#   '#제주시맛집',
#   '#애월맛집',
#   '#중문맛집',
#   '#제주공항맛집',
#   '#서귀포맛집',
#   '#산방산맛집',
#   '#신제주맛집',
#   '#제주시청맛집',
#   '#제주애월맛집',
#   '#월정리맛집',
#   '#제주여행',
#   '#제주핫플']]

# %%
def move_next(driver):
    right = driver.find_element(By.CSS_SELECTOR, 'div.l8mY4.feth3')
    right.click()
    time.sleep(2)
move_next(driver)

# %%
def insta_crawling(word, n):
    url = insta_search(word)
    
    driver.get(url)
    time.sleep(5)
    
    select_first(driver)
    time.sleep(5)
    
    
#     target = n
    results = []
    
    for i in range(n):
        try:
            data = get_content(driver)
            results.append(data)
            move_next(driver)
            
        except:
            time.sleep(2)
            move_next(driver)
            
    return(results)

# %%
results = insta_crawling('제주도맛집', n =10)
results
# Out:
# [['.❤서귀포 "제주섬나무"❤유부초밥들이 너무 이뿌게 날기다리구있어..맛좋은 유부초밥들이 다양한 종류가😍😍요기요기 있다구 그리고 우동국물한입에유부초밥한입 먹으면 그..맛 절대 잊을수없다😭 @같이 달려가서 음식들 부술친구소환!@✔매장 전화번호 : 064-738-3512✔인스타그램 아이디 : @jeju_sumnamu✔주소 : 제주도 서귀포시 김정문화로 47 B103호#제주맛집 #제주도맛집 #제주공항근처맛집 #제주시맛집 #애월맛집 #중문맛집 #제주공항맛집 #서귀포맛집 #산방산맛집 #신제주맛집 #제주시청맛집 #제주애월맛집 #월정리맛집 #제주여행 #제주핫플',
#   '2022-01-24',
#   '1,096',
#   '',
#   ['#제주맛집',
#    '#제주도맛집',
#    '#제주공항근처맛집',
#    '#제주시맛집',
#    '#애월맛집',
#    '#중문맛집',
#    '#제주공항맛집',
#    '#서귀포맛집',
#    '#산방산맛집',
#    '#신제주맛집',
#    '#제주시청맛집',
#    '#제주애월맛집',
#    '#월정리맛집',
#    '#제주여행',
#    '#제주핫플']],
#  ['.🌼애월 하루하나 더 노스텔지아🌼여유로운 하루를 보내기 좋은 감성스테이 숙소!예쁘게 꾸며진 정원에서 힐링하고따듯한 야외노천탕도 즐길 수 있어~😆😆@같이 갈 사람 소환@주소: 제주 제주시 애월읍 장전로 155..#제주맛집 #제주도맛집 #제주공항근처맛집 #제주시맛집 #애월맛집 #중문맛집 #제주공항맛집 #서귀포맛집 #산방산맛집 #신제주맛집 #제주시청맛집 #제주애월맛집 #월정리맛집 #제주여행 #제주핫플',
#   '2022-01-23',
#   '1,077',
#   '',
#   ['#제주맛집',
#    '#제주도맛집',
#    '#제주공항근처맛집',
#    '#제주시맛집',
#    '#애월맛집',
#    '#중문맛집',
#    '#제주공항맛집',
#    '#서귀포맛집',
#    '#산방산맛집',
#    '#신제주맛집',
#    '#제주시청맛집',
#    '#제주애월맛집',
#    '#월정리맛집',
#    '#제주여행',
#    '#제주핫플']],
#  ['<광고>제주갈비국수가 유명한 맛집!!손님들을 위해 끝까지 최선을 다해 드실수 있도록!!! 신경쓰는 산도롱맨도롱▪️오픈시간: 07:30 - 17:00▪️전화: 064-782-5105▪️제주시 구좌읍 해맞이해안로 2284▪️매주 화요일 휴무렌터카네비는 가끔 틀리실수 있으니 폰네비로 찾아오세요~~~ ✴️ 07:30~10:00 여유롭게 식사가 가능합니다.#성산일출봉맛집 #성산아침식사 #성산맛집#제주맛집 #제주여행 #종달리 #종달리맛집#우도여행 #성산항 #성산항맛집 #종달항#제주도맛집 #우도가는길 #우도여행코스 #우도#제주카페 #종달리수국길 #우도맛집',
#   '2022-01-23',
#   0,
#   '',
#   ['#성산일출봉맛집',
#    '#성산아침식사',
#    '#성산맛집',
#    '#제주맛집',
#    '#제주여행',
#    '#종달리',
#    '#종달리맛집',
#    '#우도여행',
#    '#성산항',
#    '#성산항맛집',
#    '#종달항',
#    '#제주도맛집',
#    '#우도가는길',
#    '#우도여행코스',
#    '#우도',
#    '#제주카페',
#    '#종달리수국길',
#    '#우도맛집']],
#  ['.⠀재주 많은 제주⠀#월정리갈비밥', '2022-01-24', '191', '제주도 제주', ['#월정리갈비밥']],
#  ['.🌼애월 하루하나 더 노스텔지아🌼여유로운 하루를 보내기 좋은 감성스테이 숙소!예쁘게 꾸며진 정원에서 힐링하고따듯한 야외노천탕도 즐길 수 있어~😆😆@같이 갈 사람 소환@주소: 제주 제주시 애월읍 장전로 155..#제주맛집 #제주도맛집 #제주공항근처맛집 #제주시맛집 #애월맛집 #중문맛집 #제주공항맛집 #서귀포맛집 #산방산맛집 #신제주맛집 #제주시청맛집 #제주애월맛집 #월정리맛집 #제주여행 #제주핫플',
#   '2022-01-23',
#   '1,408',
#   '',
#   ['#제주맛집',
#    '#제주도맛집',
#    '#제주공항근처맛집',
#    '#제주시맛집',
#    '#애월맛집',
#    '#중문맛집',
#    '#제주공항맛집',
#    '#서귀포맛집',
#    '#산방산맛집',
#    '#신제주맛집',
#    '#제주시청맛집',
#    '#제주애월맛집',
#    '#월정리맛집',
#    '#제주여행',
#    '#제주핫플']],
#  ['#제주도맛집 (광고)#산도롱맨도롱마라맛 홍갈비국수,쌀국수맛 백갈비국수육전, 꼬마김밥, 돔베고기까지비주얼도 맛도 취향 저격❤❤바로 앞 바다도 완전 제주 분위기🌊🌊#제주성산맛집 #제주갈비국수 #제주맛집 #성산일출봉맛집 #종달리맛집',
#   '2022-01-24',
#   '1,257',
#   '',
#   ['#제주도맛집',
#    '#산도롱맨도롱마라맛',
#    '#제주성산맛집',
#    '#제주갈비국수',
#    '#제주맛집',
#    '#성산일출봉맛집',
#    '#종달리맛집']],
#  ['기온은 따뜻한데 칼바람이 부는 날이예요🥲아침부터 포장예약이 많으신 걸 보니,따뜻한 아랫목에서 맛난 음식 드시면서 여유를 즐기시는 분들이 많으신 건가요?!☺따뜻한 스튜도 준비되어 있습니다🙋\u200d♀️이번 주 금요일 ( 28일 ) 정기 휴무일부터 일주일간 명절 겸 겨울방학으로 쉬어갑니다🙏자세한 휴무일정은 프로필 상단 스토리 하이라이트, 네이버 참고 부탁드립니다🙇\u200d♀️전 메뉴 포장 가능하며,도착 30분 전 전화주시면 시간 맞춰 포장 도와드리겠습니다🙆\u200d♀️오늘도 #안녕하샌',
#   '2022-01-24',
#   '442',
#   '월정리해변',
#   ['#안녕하샌']],
#  ['<광고>산도롱맨도롱 🍜 갈비국수는 흑돼지 생갈비로 만든 국수이고 두 종류입니다1. 홍갈비국수: 매콤한 육수로 강렬한 인상을 주는 맛2. 백갈비국수: 진한 육수 본연의 맛을 즐기고 싶은 분들께 추천 두분이 방문하신다면 홍갈비국수와 백갈비국수를 하나씩 시켜 나눠드시면 정말 좋구요. 커플세트등 다양하게 즐길 수 있는 메뉴들을 구성해 두었습니다 오늘도 산도롱맨도롱하세요💕✔손소독제 항시 배치 (입장시 입구부터 손소독제 마스크 착용후 입장 가능합니다⛔)▪️오픈시간: 07:30 - 17:00▪️전화: 064-782-5105▪️제주시 구좌읍 해맞이해안로 2284▪️매주 화요일 휴무✴️ 07:30~10:00 여유롭게 식사가 가능합니다.#성산맛집 #종달리맛집 #구좌맛집 #제주맛집 #제주도맛집 #성산일출봉맛집 #제주고기국수 #제주고기국수맛집#세화맛집 #김녕맛집 #광치기해변맛집 #비자림맛집 #종달리맛집 #우도맛집#제주카페',
#   '2022-01-24',
#   0,
#   '',
#   ['#성산맛집',
#    '#종달리맛집',
#    '#구좌맛집',
#    '#제주맛집',
#    '#제주도맛집',
#    '#성산일출봉맛집',
#    '#제주고기국수',
#    '#제주고기국수맛집',
#    '#세화맛집',
#    '#김녕맛집',
#    '#광치기해변맛집',
#    '#비자림맛집',
#    '#종달리맛집',
#    '#우도맛집',
#    '#제주카페']],
#  ['...제주도민이 추천맛집.#충민정-제주공항5분, 연예인도 가는 제주 왕 통갈치 맛집#모뉴에트-제주 구좌읍, 겉바속촉 까눌레맛집#도두해녀의집-제주도두봉, 전복이 가득들은 전복물회맛집.#제주공항맛집 #제주공항근처맛집 #제주도여행 #제주여행코스 #서귀포맛집 #제주갈치구이 #제주맛집 #제주맛집추천 #제주에서뭐하지 #서귀포카페 #제주도맛집 #제주핫플 #제주가볼만한곳 #제주살이 #제주도민맛집',
#   '2022-01-24',
#   '169',
#   '제주도',
#   ['#충민정-제주공항5분',
#    '#모뉴에트-제주',
#    '#도두해녀의집-제주도두봉',
#    '#제주공항맛집',
#    '#제주공항근처맛집',
#    '#제주도여행',
#    '#제주여행코스',
#    '#서귀포맛집',
#    '#제주갈치구이',
#    '#제주맛집',
#    '#제주맛집추천',
#    '#제주에서뭐하지',
#    '#서귀포카페',
#    '#제주도맛집',
#    '#제주핫플',
#    '#제주가볼만한곳',
#    '#제주살이',
#    '#제주도민맛집']],
#  ['#서귀포맛집#만족한상회역시 제주 여행은 현지인 맛집 가는 맛입니다^^이번에 알게된 갈치구이집은 제주맛집 탑에 드네요다음에도 방문할거임~~^^...#제주갈치구이맛집#제주갈치조림#중문맛집#제주도민맛집#중문맛집만족한상회#제주도맛집#중문갈치조림맛집#제주갈치조림맛집',
#   '2022-01-24',
#   0,
#   '',
#   ['#서귀포맛집',
#    '#만족한상회역시',
#    '#제주갈치구이맛집',
#    '#제주갈치조림',
#    '#중문맛집',
#    '#제주도민맛집',
#    '#중문맛집만족한상회',
#    '#제주도맛집',
#    '#중문갈치조림맛집',
#    '#제주갈치조림맛집']]]

# %%
result_df = pd.DataFrame(results)
result_df.columns = ['content', 'date', 'like', 'place', 'tags']

result_df.head()
# Out:
#                                              content        date   like  \
# 0  .❤서귀포 "제주섬나무"❤유부초밥들이 너무 이뿌게 날기다리구있어..맛좋은 유부초밥들...  2022-01-24  1,096
# 1  .🌼애월 하루하나 더 노스텔지아🌼여유로운 하루를 보내기 좋은 감성스테이 숙소!예쁘게...  2022-01-23  1,077
# 2  <광고>제주갈비국수가 유명한 맛집!!손님들을 위해 끝까지 최선을 다해 드실수 있도록...  2022-01-23      0
# 3                                 .⠀재주 많은 제주⠀#월정리갈비밥  2022-01-24    191
# 4  .🌼애월 하루하나 더 노스텔지아🌼여유로운 하루를 보내기 좋은 감성스테이 숙소!예쁘게...  2022-01-23  1,408
#
#     place                                               tags
# 0          [#제주맛집, #제주도맛집, #제주공항근처맛집, #제주시맛집, #애월맛집, #중문맛...
# 1          [#제주맛집, #제주도맛집, #제주공항근처맛집, #제주시맛집, #애월맛집, #중문맛...
# 2          [#성산일출봉맛집, #성산아침식사, #성산맛집, #제주맛집, #제주여행, #종달리,...
# 3  제주도 제주                                          [#월정리갈비밥]
# 4          [#제주맛집, #제주도맛집, #제주공항근처맛집, #제주시맛집, #애월맛집, #중문맛...

# %%
# result_df.to_excel('./newfiles/new_data.xlsx', index = False)

# %%
jeju_insta_df = pd.DataFrame()

f_list = ['1_crawling_jejudoMatJip.xlsx', '1_crawling_jejudoGwanGwang.xlsx', '1_crawling_jejuMatJip.xlsx', '1_crawling_jejuYeoHang.xlsx']

for fname in f_list:
    fpath = 'C:/Users/jhjh3/class/datasalon-master/02_data_class/5_Jeju_Hotplace/files/' + fname
    temp = pd.read_excel(fpath)
    jeju_insta_df = jeju_insta_df.append(temp)

# %%
jeju_insta_df.drop_duplicates(subset= ['content'], inplace = True)
jeju_insta_df.shape
# Out:
# (8369, 5)

# %%
# jeju_insta_df.to_excel('./newfiles/1_crawling_raw.xlsx', index = False)

# %% [markdown]
# ### 지도 시각화

# %%
raw_total = pd.read_excel('C:/Users/jhjh3/class/datasalon-master/02_data_class/5_Jeju_Hotplace/files/1_crawling_raw.xlsx')
raw_total.head()
# Out:
#                                              content        date   like  \
# 0  더 늦기전에 제주도로 떠나쟈😍.#제주핫플레이스 간단히 1탄 모아봄!#제주여행 요 필...  2018-12-07  1,402
# 1  12월에 제주도를 가야하는이유🍊.#제주핫플 모음 끝판왕😍이거 하나면 겨울 #제주여행...  2018-12-03    368
# 2  11월 놓치지 말아야 할 제주 관광.가을바람이 최고조에 이르는 11월추운 겨울을 앞...  2018-11-02    166
# 3  국민학교세대#제주관광#제주살이#제주이주민#아라동주민#삼남매집 #새해첫날#드라이브#명...  2019-01-01     28
# 4  #제주관광 #제주 #돔나이트 #스트레스 #풀자 #춤추며 #땀날려 #가끔은괜찮아 #인...  2019-01-01     12
#
#     place                                               tags
# 0     NaN  ['#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가...
# 1     NaN  ['#제주핫플', '#제주여행', '#제주', '#제주도', '#제주도맛집', '#...
# 2     NaN  ['#honestin', '#어니스틴', '#제주여행', '#제주', '#제주도',...
# 3  명월국민학교  ['#제주관광', '#제주살이', '#제주이주민', '#아라동주민', '#삼남매집'...
# 4     NaN  ['#제주관광', '#제주', '#돔나이트', '#스트레스', '#풀자', '#춤추...

# %%
location_counts = raw_total['place'].value_counts()

type(location_counts)
# Out:
# pandas.core.series.Series

# %%
location_counts_df = pd.DataFrame(location_counts)
type(location_counts_df)
location_counts_df.head()

# location_counts_df.to_excel('./files/3_location_counts.xlsx', index =True)
# Out:
#                       place
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108
# Seogwipo                 66
# 제주도 크리스마스 박물관            59

# %%
locations = list(location_counts_df.index)
locations
# Out:
# ['Jeju',
#  'Jeju-do',
#  'Jungle Book by Alice',
#  'Seogwipo',
#  '제주도 크리스마스 박물관',
#  '할로비치',
#  '제주에인감귤밭',
#  'Jeju Island',
#  '성산일출봉 城山日出峰  Seongsan Ilchulbong',
#  '폼포코식당_pompokokitchen',
#  '1100고지',
#  'Nimome',
#  '월정리해변',
#  '고집돌우럭중문점',
#  '석부작박물관',
#  '제주도 애월읍',
#  '알뜨르 비행장',
#  '카멜리아 힐',
#  '제주레포츠랜드',
#  '밥깡패',
#  '제주 함덕 서우봉 해변',
#  '제주도 서귀포 중문관광단지 濟州島西歸浦中文觀光團地',
#  '제주고궁한복카페 jeju gogung hanbok studio',
#  '위미동백나무군락지',
#  '제주신화월드 Jeju Shinhwa World',
#  'Woljeongri Beach',
#  '협재해변 Beach',
#  '연동 바오젠 거리',
#  '김녕미로공원 Jeju Kimnyoung Maze Park',
#  '고래배꼽',
#  '제주 성산 신산포구자연산횟집 회포장',
#  '새별오름',
#  '용머리해안',
#  '용눈이오름',
#  '캔디원',
#  '사려니숲길',
#  '하이엔드 제주',
#  '제주빅볼랜드',
#  '서귀포 느영나영 게스트하우스',
#  '휴애리 자연생활공원',
#  '옹포리',
#  '삼무공원',
#  '마마뜰',
#  '제주어린왕자게스트하우스',
#  '위미동백나무군락',
#  '제주커피박물관 Baum',
#  'Jeju Aewol',
#  '한라산',
#  '위미2리 동백군락지',
#  'Jeju Island 제주특별자치도 济州道',
#  '광치기해변',
#  '서우봉',
#  '제주해남',
#  '한라산 (漢拏山, Hallasan)',
#  '카페한라산',
#  '성이시돌목장',
#  '제주 송악산',
#  '옹포별장가든',
#  '월정리카페콧수염',
#  '牛岛 Udo Island 우도',
#  '곽지해수욕장',
#  '카페브리프',
#  '아줄레주',
#  '에코랜드',
#  '산굼부리',
#  '제주 꿈꾸는고래 스쿠버&게스트하우스',
#  'Terarosa - 테라로사',
#  'Casa Linda Guesthouse-까사 린다 펜션',
#  '고집돌우럭-gozipfish',
#  'the cliff jeju - 더클리프 제주',
#  '세화해수욕장',
#  '디저트쌀롱 톨',
#  '번개과학체험관',
#  'Hidden Cliff / 히든 클리프',
#  '오전열한시',
#  '하도핑크',
#  '오후새우시',
#  '르페도라펜션',
#  '제주 협재 해수욕장',
#  '소세지가게',
#  '면차롱',
#  '제주신라호텔',
#  '친봉산장',
#  '오설록티뮤지엄',
#  '주상절리대',
#  '로타리과자점',
#  '르토아베이스먼트',
#  '비자림',
#  '노라바',
#  '퍼시픽랜드 - Pacific Land JEJU',
#  '제주동문재래시장',
#  '우아당',
#  '우드노트',
#  'LOTTE Hotel Jeju 롯데호텔제주',
#  '춘심이네 본점',
#  '서귀포 매일올레시장',
#  '함덕487',
#  '녹근로33',
#  'Paris, France',
#  '명월국민학교',
#  '커피캄머',
#  '남원큰엉해안경승지',
#  '아날로그감귤체험',
#  '탐라반상',
#  '플레이스 캠프 제주',
#  '만월당',
#  '성산일출봉 게스트하우스 파티 띵까게스트하우스',
#  'Busan, South Korea',
#  '새별오름 (Saebyul Orum)',
#  '해발1950m 한라산 백록담',
#  '제주도',
#  '수목원테마파크',
#  'Hidden Cliff Hotel & Nature',
#  '지금이순간카페',
#  '제주꿈꾸는고래',
#  'Jungmun Beach',
#  'Sunnyside Beachclub Jeju',
#  'The Shilla Jeju',
#  '함덕반하다',
#  'Jeju International Airport',
#  '몽상드 애월 (Mônsant)',
#  '하늘아래 게스트하우스',
#  '서귀포항',
#  '명랑스낵',
#  '제주여행',
#  '붉은제주',
#  '아뜰리에안',
#  '푸른섬 제주도',
#  "블레블랑제리 Ble' Boulangerie",
#  '설심당본점',
#  '한라수목원',
#  '제주도 월정리',
#  '앙뚜아네트',
#  '안녕김녕sea',
#  '돈사돈',
#  'Jeju horse Riding farm',
#  '다람쥐식탁',
#  '환상의 섬 Jeju Island',
#  '쿠주',
#  '제주국제공항',
#  '커피파인더coffeefinder제주시청',
#  '양가형제',
#  'Seoul, South Korea',
#  '이익새양과점',
#  '제주도 세화해변',
#  'Harmduck Beach in Jeju Island',
#  '안녕협재씨',
#  '스윗슬로cafe',
#  '제주도 해안도로',
#  '하례정원',
#  '제주도 서귀포',
#  '쇠소깍',
#  '애월늘',
#  'Guzasien -구좌지앵',
#  '제주 한라산 영실코스',
#  '혜화동버거',
#  'Jejudo',
#  '제주 산굼부리',
#  '대평리',
#  '금능해변',
#  '다랑쉬오름',
#  '보름우스테이',
#  '법환동',
#  '천지연폭포 (Cheonjiyeon Waterfall)',
#  '로얄',
#  '선녀와나무꾼',
#  'Hamdeok Jeju',
#  '제주 남원리',
#  '인생밥집',
#  '서귀포시 성산읍',
#  '아름다운 제주도',
#  '유동커피',
#  '구좌읍 평대리',
#  '용연구름다리',
#  '이중섭 거리',
#  '카페루핀',
#  '성산갯마을식당',
#  'Osulloc Tea Museum',
#  '제주시 아라동',
#  '어조횟집',
#  '짱구분식',
#  '김영갑갤러리 두모악',
#  '앤트러사이트 제주 한림점',
#  '평대우유차',
#  '제주 서귀포 그릴 데미그라스',
#  '서울맛집',
#  'Meal Table Garden',
#  'Vadada 바다다',
#  '이런날엔',
#  '신설오름',
#  '하얏트 리젠시 제주ㅣHyatt Regency Jeju',
#  '쌀다방',
#  '제주 윗세오름',
#  '다미진횟집',
#  '남원읍 신례리',
#  'Teddy Bear Museum - 제주 테디베어뮤지엄',
#  '가시식당',
#  '이호테우해변',
#  '외쿡식당',
#  '문치비',
#  '훈이네고사리육개장',
#  'Hotel Alfonso XIII, a Luxury Collection Hotel, Seville',
#  '탐나버거',
#  '김녕회관',
#  '보엠 - Bohème',
#  '말젯문',
#  '우도',
#  '박물관이살아있다',
#  '군산오름',
#  '성산일출봉',
#  '카페주비 - JUBI',
#  '그러므로part.2',
#  '토스카나호텔',
#  '로맨틱무브',
#  '광안리 해수욕장 - 廣安里海水浴場 GwangalliBeach, Busan, South Korea',
#  '한림칼국수',
#  '평대리 해변',
#  '핏제리아마노',
#  'Ulsan, South Korea',
#  '모슬 포항',
#  '제주도 한경면',
#  '서귀포흑돈',
#  '켄싱턴 제주호텔',
#  '순옥이네명가',
#  '지오반니',
#  '영육일삼',
#  '함덕호랑이',
#  '센트로',
#  'CAFE E.P.L',
#  '애월해안가',
#  '모슬포항 만선식당',
#  '신창풍차해안도로',
#  'Hotel NANTA 호텔 난타',
#  '테지움 제주',
#  'Jeju_Gimnyeong_Maze_Park',
#  '동굴카페 다희연(Cafe Daheeyeon in the Cave)',
#  '목장카페 드르쿰다',
#  '삼미흑돼지',
#  '제주마방목지',
#  '그계절',
#  '판포포구',
#  '중문 덤장',
#  'Daegu, South Korea',
#  'Longlive',
#  '문쏘',
#  '우동가게',
#  '하도리1091',
#  '성읍민속마을',
#  '대정읍',
#  '제주 도두동',
#  '다다의작은공간',
#  '블리스찬',
#  'Salon de Lavant',
#  '황우지해안',
#  '새연교횟집',
#  '한림항',
#  '오롯',
#  '이정의댁',
#  '부두식당',
#  '붉은못허브팜 Cafe Redpond 애월본점',
#  '제주돌마을공원',
#  '2월22일 브런치카페',
#  '천제연폭포',
#  '선흘리 동백동산',
#  'Cafe148',
#  '뉴저지카페',
#  '쿠오모제주',
#  '백약이 오름',
#  '제주 휴애리',
#  '비브레이브 커피 로스터즈',
#  '가시아방',
#  '제주시 동문시장',
#  '꽃기린 카페',
#  '판포리',
#  '족황상제',
#  '그초록',
#  '만세국수삼성혈점',
#  '컴피하우스',
#  '복자씨연탄구이',
#  '제주 조류공원 화조원',
#  '윗세오름(해발 1700M)',
#  '이음',
#  '용두암',
#  '아쿠아 플라넷 제주 (Aqua Planet JEJU)',
#  '소보리당로 222',
#  '제주 구좌읍 세화리',
#  '스튜디오 쿠나',
#  '빨간머리몽게스트하우스',
#  '남원읍 위미리 귤밭',
#  '제주허브동산',
#  '슬슬슬로우',
#  '아부오름',
#  '볼스카페',
#  '테쉬폰',
#  '올레7코스',
#  '済州島 - チェジュ島',
#  '상호네숯불구이',
#  '테디베어뮤지엄',
#  '서귀포 까망돼지',
#  'Hamdoek Beach, Jeju Island',
#  '호텔 몽듀',
#  '제주도 천지연 폭포',
#  '모뉴에트',
#  'JEJU앨리스',
#  'Ecoland Theme Park Forest Train黃花小火車',
#  '라온더마파크',
#  '자매국수 노형점',
#  '제주 이호해수욕장',
#  '그리울땐 제주',
#  '천지연폭포',
#  '천왕사 (天王寺)',
#  '초밥충전',
#  '연정식당',
#  'Oedolgae Jeju',
#  '해왓',
#  '제주서커스월드공연장',
#  '로컬크랩',
#  '제주시외버스터미널',
#  '봄날',
#  '대우정',
#  '갈중이',
#  '밥의정석',
#  '바닐라파레트',
#  '한동올레펜션',
#  '중문색달해변 (Jungmun Saekdal Beach)',
#  '카페두가시',
#  '빨간모자마법사',
#  '따라비오름',
#  '아도록',
#  '한담해안산책로',
#  'Namwon Seogwipo Jeju,South korea',
#  '칠돈가',
#  '사라봉근처',
#  '함덕해변',
#  '난드르바당',
#  'Antoinette',
#  'South Korea',
#  '형제국수',
#  '애월더선셋',
#  '제스토리, 바이제주, 제주감성소품',
#  'Hyatt Regency, Jeju Island',
#  '제주도 전주횟집',
#  '제주김만복',
#  '토끼썸',
#  '삼공주회센터',
#  '숨비아일랜드',
#  '빌라드아토',
#  'Uncommon Table',
#  '모메든식당',
#  '이게밥도둑',
#  '쉐프부부',
#  'Bongcheon-dong',
#  '지금여기',
#  '홍키호테',
#  '타쿠마 - Takuma',
#  '카페모리&베이커스트리트',
#  '헤이브라더',
#  '올레안뜰',
#  '젠하이드어웨이',
#  '소우',
#  'Gwakji Beaches',
#  '비스트로낭',
#  'Salon De 소자38',
#  '수제홍과일모찌하귀점',
#  '충남 대천 해수욕장 에서',
#  'Jamae Guksu',
#  '도라지식당',
#  '호박다방',
#  '중문 단지 삼원정',
#  '마모루',
#  '라비에 와인비스트로',
#  '카페바띠',
#  '리틀이태리 비스트로',
#  '제주엠리조트',
#  '섶섬해녀할망카페',
#  '풍미독서',
#  '털보네고양이',
#  '가드망제',
#  '마구로쇼쿠도',
#  '쿠쿠아림',
#  '바굥식당',
#  '어라운드 폴리 Around Follie',
#  '시루애월 소길점',
#  '제주시동문시장',
#  '바람코지 게스트하우스&카페',
#  '삼다버거',
#  '마포식당',
#  '한모살식당',
#  '어반가라지',
#  '홍대개미제주',
#  '카페송키',
#  '미미본가',
#  '바당지기식당',
#  '서귀포 기억나는집',
#  '버드나무집',
#  'Coco Mama',
#  '소금바치 순이네',
#  '아산 음봉',
#  '하노이안브라더스',
#  '군산 정상',
#  '반딧불 한담',
#  '과일애',
#  '제주 사랑분식',
#  '제주한면가 濟州韓麵家',
#  '못생김',
#  '중문국수나라',
#  'Cafe멘도롱',
#  '드렁큰디제이',
#  '협재칼국수',
#  '시민갈비',
#  '우진해장국',
#  '로드129',
#  '자갈자갈',
#  '팀버 커피 제주',
#  '제주시',
#  '공천포 식당',
#  '해바라기 분식',
#  '해비치호텔&리조트 - Haevichi hotel & resort',
#  '벵디',
#  'Cafe카페인',
#  '봉개동',
#  '베이크샵스니프 bakeshop sniff',
#  '쭈니창고',
#  '장복호',
#  '모이세해장국',
#  '제주인의밥상',
#  '하례리 망장포구',
#  '제주시 조천읍 와선로 206',
#  '오조해녀의집',
#  '쉼표',
#  '독개물항',
#  'Mansion37.5',
#  '월정곰닭',
#  '포팩토리',
#  '탑동마차',
#  '1342틈',
#  '백리향백반',
#  '푸릇프릍',
#  '북촌플레이스',
#  '마레벤또',
#  'U-do Bong( 우도봉)',
#  "동광 pâtisserie '東光'",
#  '오메오메동문시장점',
#  '도토리키친',
#  '지붕위제주바다',
#  '연화키친',
#  '제주시농협하나로마트',
#  '돈테일러익스프레',
#  "서귀동 298-5 '세계의 가정식'",
#  '훈남횟집',
#  '제주시청',
#  '702키친',
#  '바라크라',
#  '제주도청',
#  'Bonte museum',
#  '제주 팜스빌리지',
#  '김녕장',
#  '서귀포 워터월드',
#  '오설록',
#  '상효원 수목원',
#  '제주워터월드/감귤노천탕',
#  '애월해안도로',
#  '투썸플레이스 제주애월한담점',
#  '유민 아르누보 콜렉션',
#  '몽키비치',
#  '안녕, 육지사람',
#  '제주롯데시네마',
#  'Soror',
#  '신창해안도로',
#  '다이브스테이',
#  '저녁정원',
#  '금악리 제주힐링리조트',
#  '고근산정상',
#  '효돈마을',
#  '한화아쿠아넷',
#  'Volskafé',
#  'Maxim 모카다방',
#  '서건도',
#  '외돌개',
#  '성산일출봉 코앞 쉼터',
#  'Seosan',
#  '에코그린리조트',
#  '구엄리 돌염전',
#  'Ramada Plaza Jeju',
#  '골목카페 옥수',
#  '해물뚝배기전문 재암식당',
#  '블루마린하우스',
#  '고기마씸',
#  '협재술시',
#  'Saeyeon Bridge, Jeju Island',
#  '테라로사-이사랑',
#  '구좌상회',
#  '깡촌흑돼지',
#  '개똥이네 동물원',
#  '제주도 용두암',
#  '중문 마린파크 퍼시픽랜드',
#  'Oslob, Cebu',
#  '十五夜 siboya 십오야',
#  '폴레폴레게스트하우스 -Polepole Guesthouse in Jeju',
#  'Ocean Suites Jeju Hotel',
#  '전주콩나물국밥',
#  '박물관은 살아있다 제주 중문',
#  '명진전복',
#  '헤이미쉬제주_제주독채펜션',
#  '하도해변',
#  '송당리 풍림다방',
#  '중문관광단지 (Jungmun Tourism Complex)',
#  '호연스테이',
#  '한성식당',
#  '제주항공',
#  '포근한우리집',
#  '스물다섯',
#  'Cafe가호',
#  '카페소금',
#  '비양도 해녀촌',
#  '네이처트레일',
#  '반디앤로제이',
#  '카페라능',
#  '대구국제공항',
#  '이중섭 미술관',
#  '오운커피',
#  '타시텔레',
#  '사락',
#  '모던하우스 제주점',
#  '카페하도섬/엠스테이펜션',
#  '돈사돈중문점',
#  '썬앤문리조트',
#  '73st',
#  '서귀포 칼호텔 (KAL Hotel Seogwipo)',
#  '성산포',
#  '제주카페 스르륵',
#  '나주혁신도시',
#  'playce',
#  '하늘고래',
#  '신천목장',
#  '섭지코지 (Seopjikoji)',
#  '제주좋은날',
#  '호끌락80번지',
#  '벵디1967',
#  '우도 비양도',
#  '비싸이드엠,beside-M',
#  '제주초가집 곱들락',
#  '헤밍웨이 하우스',
#  '조천읍 북촌리',
#  '인공위성 제주',
#  '제주도립미술관',
#  '협재',
#  '제주인에이에이',
#  '제주도 표선',
#  '네이처캔바스',
#  '머스태쉬커피/머스태쉬하우스',
#  'Paz',
#  '마담제 게스트하우스',
#  '단디501',
#  '제주 성산읍',
#  'Kairos jeju',
#  '방주교회',
#  '카이로스 제주',
#  'TheFirst70 Hotel',
#  'ECOLAND theme park',
#  '켄싱턴리조트 서귀포',
#  '국수의 전설',
#  '시리우스 호텔',
#  '나도섬이다',
#  'Howard Johnson Jeju Yeondong Hotel - 하워드존슨 제주 연동 호텔',
#  '제주김만복본점',
#  '이호테우 목마등대',
#  'BUTTON STAY 단추스테이 게스트하우스',
#  '고불락 식당',
#  '제주조천스위스마을',
#  '수망일기',
#  '올레 6코스 (Olle Route 6)',
#  '사우스바운더 Southbounder Brewery',
#  '차귀도',
#  '까망고띠',
#  '함덕 다래향',
#  '돈사촌',
#  '꽃이다카페',
#  '세종시',
#  '잔향',
#  '시루애월카페',
#  '꽃밥',
#  'Cultured',
#  '빌리엔젤 제주노형점',
#  '공업탑',
#  '고로케야',
#  'Shilla Stay',
#  '내콩가',
#  '스테이굿무드',
#  '해심가든',
#  '수카사',
#  '제주 월령선인장 군락지',
#  'Bronx, New York',
#  'The Retrieve',
#  '제주 이호테우 해변',
#  '여름문구사',
#  '객의하우스',
#  '섭지코지 등대',
#  '더아트스테이호텔-The Artstay Hotel',
#  'MBC',
#  '오렌지블루스',
#  '제주도 휘닉스아일랜드',
#  '지붕 위 제주바다',
#  'Cafe delmundo',
#  '금능반지하',
#  '달사막',
#  '절물 자연 휴양림',
#  'Tj Guesthouse',
#  'Gimpo International Airport - 金浦国际机场 - 김포공항',
#  '카페어떤오후',
#  '협재 수우동',
#  'M-STAY / 엠스테이',
#  'La Tortuga',
#  '비긴어게인펜션',
#  '바램목장&카페',
#  '산방굴사 (Sanbanggulsa Temple 山房窟寺)',
#  '종달스토리 게스트하우스',
#  '색달식당',
#  '책다방',
#  '동문시장',
#  '표선리',
#  '자구리 카페 몬들락 Cafe Mondeulrak',
#  '사라오름 산정호수',
#  '제주도 고근산',
#  '제주마로 펜션',
#  '책방무사',
#  '항파두리 항몽유적지',
#  '블루라군다이브-bluelagoondive',
#  'Hwasun',
#  '베케',
#  '제주도 하늘 위',
#  '제주맑음',
#  '스테이 비갠오후',
#  '제주 반디앤로제이 펜션 & 플라워브런치카페',
#  '종달리 해변',
#  '제주돌문화공원',
#  '피규어뮤지엄제주',
#  '한동리 화수목',
#  'Enough, 이너프',
#  '함덕 Fishya',
#  '표선 해비치해수욕장',
#  '게으른날',
#  '에코랜드테마파크',
#  '원더먼트제주',
#  '시월의리브라',
#  '카페닐스',
#  '평화통일불사리탑사',
#  '담앤루리조트',
#  '한라산 정상 해발 1,950m',
#  '우리두리게스트하우스',
#  '목수금토일',
#  'Gimpo International Airport Station',
#  '제주국제공항 활주로 (Jeju Airport Runway)',
#  '정동진',
#  '수제홍과일모찌',
#  '돌마을공원',
#  '서머셋 제주신화월드',
#  '아름다운제주여행',
#  '노리매',
#  '탑동해변공연장',
#  '산방산',
#  '제주세계자연유산센터',
#  'Suweolbong Trekking',
#  '제주 나인브릿지 CC',
#  '제주도 부영리조트',
#  '화순금모래해변',
#  '연북정',
#  '제주신라면세점',
#  '니모메빈티지라운지',
#  '나인브릿지',
#  '월정스캔들',
#  '노형 수목원가는길',
#  '저지예술인마을',
#  '기원뚝배기',
#  '산방산 (Sanbangsan)',
#  'Ocean Suite Jeju Hotel (오션스위츠제주호텔)',
#  '제주오리엔탈호텔',
#  '제주웰컴센터',
#  '새별오름 정상',
#  '돼지촌',
#  '에코랜드 라벤다앤그린티로즈가든역',
#  'Jeju National University',
#  'Jeju Island, South Korea - 제주도',
#  '웃뜨르',
#  '대굴대굴굴구이',
#  '용담해안도로',
#  '정방폭포가 보이는 암벽위',
#  '카페2472',
#  '쪼끌락 cafe',
#  '동한두기',
#  '더스파',
#  '제주중앙로상점가',
#  '환상숲곶자왈공원',
#  '휘슬락호텔',
#  '올레길 5코스',
#  '닭머르',
#  '미나마라',
#  '성산수구레국밥',
#  '탑동광장편의점',
#  '제주 생각하는 정원',
#  'Dammann Frères_다만프레르_제주신화점',
#  '제주대학교 교양강의동',
#  '돌담너머바다',
#  '강식당',
#  '성수족발',
#  '덕수하루펜션',
#  '바다의집',
#  '카페 호꼼',
#  '스모크하우스인구억',
#  '전라북도 군산 경암동 철길마을',
#  '속초 아바이마을',
#  '한림 칠돈가',
#  '제주집',
#  'Jungle book by Alice',
#  '문섬',
#  '부산 맛집 여기',
#  'LOTTE City Hotel Jeju 롯데시티호텔제주',
#  '제주몬트락',
#  '청사포 수민이네',
#  '옥계휴게소',
#  '스타양곱창',
#  '선화동106-1',
#  '제주 운정이네',
#  '필립헤어',
#  'Ulsan, Korea',
#  '제주도 한림',
#  '착한스시',
#  '협제 혜변',
#  '보목',
#  '제주아리아',
#  '한림공원 Hallimpark',
#  'Saturdayisland',
#  '서귀포 이마트',
#  'Cafe Koomda',
#  'Seoul, Korea',
#  '한라생태숲',
#  '제주아트리움"비밀의그림자"공연',
#  '관덕정',
#  '알뜨르프로젝트2018',
#  '엉또폭포',
#  '유리의성과마법의숲',
#  '동문로터리',
#  '제주여행 가야밀면',
#  '접대 - 저번에 우리가 만났던 그때',
#  '광안리 앙상블',
#  '윈드스톤',
#  'Sensō-ji',
#  '용두암해변',
#  '날것',
#  '큰엉전망대쉼터',
#  'Cafe기억해',
#  '사계여행',
#  '스타벅스 제주성산dt점',
#  'Maison GLAD Jeju - 메종글래드 제주',
#  '호텔 아이엠',
#  '제주프레임스파빌',
#  '오샹띠',
#  '서귀포향토오일장',
#  '1158 Cafe',
#  '동박낭',
#  'Marevo Resort / 마레보 리조트',
#  '김녕 앞바다',
#  'Segovia, Spain',
#  '구좌상회작업실',
#  '가시아방국수',
#  '오드랑베이커리',
#  '채점석빵집',
#  '신풍목장',
#  '요요무문',
#  '제주도 하도리',
#  '바보까페',
#  '우도 하고수동해수욕장',
#  '렛츠런팜제주',
#  '제주시도두항',
#  '서귀포 법환포구',
#  'Jeju Starbucks 용담dt',
#  '외도동',
#  '순덕이네해산물장터',
#  '한복입는 선흘집',
#  '돈물국수',
#  '덕인당 소락',
#  '무수천계곡',
#  '제주시 화북동',
#  '제주거울미로 이상한나라의앨리스',
#  'Arc de Triomphe',
#  '피규어 뮤지엄 제주  Figure Museum Jeju',
#  '아날로그감귤밭',
#  '황궁쟁반짜장',
#  'Hallasan',
#  '노형로터리',
#  '금바리',
#  '건축카페 - 섶섬이보이는',
#  '도두항',
#  '서양차관',
#  'Paju',
#  'Shimo-kitazawa Station',
#  '스트라이크볼링센터',
#  '종가전복',
#  '서귀포잠수함',
#  '석부작테마공원',
#  '와흘리',
#  '초콜릿랜드 / Chocolate Land',
#  'Yacht Tour Shangri-La',
#  '정방 폭포',
#  '관음사',
#  '제주비치호텔 함덕',
#  'Sangumburi Crater',
#  '미도리',
#  '서귀포의료원',
#  'Hibi & Kohaku',
#  '호텔위드제주',
#  '산천단',
#  'Shmonga',
#  '쉬리의 언덕',
#  '코코몽 에코랜드',
#  '올레길',
#  '귀덕1리',
#  '보롬왓',
#  '랍스터빈_jeju',
#  '제주하귀휴먼시아',
#  '제주베니스랜드',
#  '고성리',
#  '더본호텔',
#  'Málaga, Spain',
#  '화북1동',
#  '자연뜨락',
#  '비양도',
#  '제주도가는 비행기 안',
#  '제주 천제연폭포',
#  '우도 (Udo / 牛島)',
#  'Teseum',
#  '비자림 (Bija Forest, 榧子林)',
#  '제주함덕 해수욕장',
#  'GD Cafe',
#  '델문도 제주 카페 Cafe Delmoondo',
#  '김녕 성세기 해변',
#  '제주도 더마파크',
#  'Halim jeju korea Selatan',
#  '제주도 귤밭',
#  '제주마라도잠수함',
#  '어부의딸',
#  '스시애월',
#  '꽃돼지연탄구이',
#  '세인트포cc',
#  '여수 앞바다',
#  '무거버거',
#  '유리네 식당',
#  '화산양꼬치2호점',
#  'Myeongjin Abalone',
#  '달달콤콤',
#  'Jaju,south Korea',
#  '규태네 양곱창',
#  'KBS본관',
#  '쇠소깍오메기식당',
#  '배블리컨테이너',
#  '마가리따 은혜씨cafe&Dining pub',
#  'Cafe Ri',
#  '神의 한모(신의 한모)',
#  '카페오길',
#  '풍원 한라산볶음밥',
#  '홍대부부',
#  '모던플레이스 리조트',
#  '성읍칠십리식당',
#  '자구내포구',
#  '남포커피',
#  '크랩잭제주',
#  '마로니에 공원',
#  'Thecoffeebrew-더커피브루',
#  '제주 신재생에너지 홍보관',
#  '한림 바당길',
#  '오마주마카롱',
#  '연동포차',
#  '양대곱',
#  '깐깐한족발',
#  '오는정 김밥',
#  '뽕끄랑',
#  '홍대 깐풍기브라더스',
#  'CAMPHORTREE Hotel & Resort',
#  '날씬흑돼지',
#  '삼보식당',
#  '주점부리',
#  '수월봉',
#  '흑돼지가있는풍경',
#  '물꼬기',
#  '블랙하우스 떡볶이레스토랑',
#  '대우정식당',
#  '청루 봉평 메밀 막국수',
#  '큰돈가',
#  '모니카옛날통닭',
#  '메이즈랜드',
#  '소렉',
#  '토도',
#  '인사리',
#  '제주시 고요남',
#  '해녀엄마의집',
#  '서촌제',
#  '제주 오션스토리',
#  '은실이네 게스트하우스',
#  '면뽑는선생 만두빚는아내',
#  '바다이야기',
#  '칠돈가 본점',
#  '에이그라운드',
#  "Jerry's PUB",
#  '제주칼국수 제주해물탕',
#  '블루밍아일랜드 Blooming Island',
#  '촵촵 - Chwap Chwap',
#  '행원포구',
#  '신흥동 일본식가옥',
#  '8월의크리스마스 초원사진관',
#  '이스트엔드',
#  '제주신화월드 메리어트 리조트관',
#  '키작은삼촌',
#  '엉장매하우스',
#  '고관해물탕, 초량',
#  '브라운스위트 제주',
#  '제주 대명리조트',
#  '제주도맛집',
#  '동탄2에 산다',
#  '청초수물회&섭국 [신관]',
#  '속초 엄지네포장마차',
#  '오라게게스트하우스',
#  '미영이네식당',
#  '내츄럴케이',
#  '제주스럽닭',
#  '바삭돈가스',
#  '새우조나단',
#  '대춘해장국',
#  '금능샌드',
#  'Novotel Ambassador Daegu',
#  '참맛나김밥',
#  '리치망고 협재점',
#  '가배',
#  '떡하니',
#  'Shineville Luxury Resort',
#  '듀블라썸',
#  '카페오드리',
#  '낙지로',
#  '키아스마',
#  '일도전복',
#  '대돈',
#  '광원',
#  '곰막 횟집',
#  '부자식당',
#  '핸드테일러 제주점',
#  '곱을락',
#  '곽지스테이션',
#  '쉬림포크shrimpork',
#  '교래 손 칼국수',
#  '사이카레',
#  '현대백화점 울산점',
#  '테디밸리골프리조트',
#  '제주중문관광단지',
#  '김포 구래동',
#  '성산스쿠버리조트',
#  '카페록록 Loklok',
#  '흑송',
#  '제주시 새우리',
#  '거멍국수',
#  '갈치왕',
#  '청춘게스트하우스',
#  'OLD STUFF 올드스터프 Coffee&bread',
#  '김녕해수욕장 (Gimnyeong Beach)',
#  '도깨비명당',
#  '서촌제 (서울촌놈인제주)',
#  '맛있는 제주',
#  '자매국수 본점',
#  "That's very",
#  '세영수산',
#  '전주도',
#  '팔도수산식당',
#  '사방팔방 외도점',
#  '남원 포구',
#  '나원횟집',
#  '미풍해장국  중앙점',
#  '대기정',
#  '유채꽃사진촬영소',
#  '정관신도시',
#  '몽구네민박',
#  'Gagamel',
#  '경성대 맛집',
#  '자연스러운식당',
#  '바다사랑그리고추억',
#  '제주송정농원',
#  '제주 이자와',
#  '우리집아점',
#  '플레이스엉물',
#  '치저스 제주',
#  '동복해녀촌',
#  '웃뜨르 우리돼지',
#  '한림 뽈살집',
#  '덕승식당',
#  '말미오름 (두산봉)',
#  '효섬마을 초가집',
#  '기쁨이네 감자탕',
#  '부촌식당',
#  '릴리펏 제주점 메종글래드호텔',
#  '담아래',
#  '제주돈아',
#  '제주한라수목원♥',
#  '민경이네 어등포해녀촌',
#  ...]

# %%
# ! pip install requests
import requests

# %%
searching = '합정 스타벅스'
url = 'http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
url
# Out:
# 'http://dapi.kakao.com/v2/local/search/keyword.json?query=합정 스타벅스'

# %%
headers = {
    "Authorization": "KakaoAK b37533f330aa94672bfb49ee94dc4dbf"
}

# %%
places = requests.get(url, headers = headers).json()
places
# Out:
# {'documents': [{'address_name': '서울 마포구 서교동 395-166',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '26572121',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 서교점',
#    'place_url': 'http://place.map.kakao.com/26572121',
#    'road_address_name': '서울 마포구 양화로 78',
#    'x': '126.916980454434',
#    'y': '37.5514601750423'},
#   {'address_name': '서울 마포구 합정동 472',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '2057327896',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 합정점',
#    'place_url': 'http://place.map.kakao.com/2057327896',
#    'road_address_name': '서울 마포구 월드컵로1길 14',
#    'x': '126.91253700818196',
#    'y': '37.54994959743763'},
#   {'address_name': '서울 마포구 서교동 490',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '288597324',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 합정폴리스R점',
#    'place_url': 'http://place.map.kakao.com/288597324',
#    'road_address_name': '서울 마포구 양화로 45',
#    'x': '126.91340049045',
#    'y': '37.5508989849269'},
#   {'address_name': '서울 마포구 서교동 490',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '27076117',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 합정메세나몰점',
#    'place_url': 'http://place.map.kakao.com/27076117',
#    'road_address_name': '서울 마포구 양화로 45',
#    'x': '126.913541853312',
#    'y': '37.5500016943689'},
#   {'address_name': '서울 마포구 서교동 475-13',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '12776689',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 망원역점',
#    'place_url': 'http://place.map.kakao.com/12776689',
#    'road_address_name': '서울 마포구 월드컵로 74',
#    'x': '126.91071941264',
#    'y': '37.5557803955969'},
#   {'address_name': '서울 마포구 서교동 374-20',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '27416913',
#    'phone': '',
#    'place_name': '스타벅스 서교동사거리',
#    'place_url': 'http://place.map.kakao.com/27416913',
#    'road_address_name': '서울 마포구 양화로 105',
#    'x': '126.918607875358',
#    'y': '37.5534723352988'},
#   {'address_name': '서울 마포구 서교동 353-5',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '1436512690',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 홍대입구역사거리R점',
#    'place_url': 'http://place.map.kakao.com/1436512690',
#    'road_address_name': '서울 마포구 양화로 125',
#    'x': '126.920317785646',
#    'y': '37.5546231745866'},
#   {'address_name': '서울 마포구 동교동 205-6',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '20705154',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 동교점',
#    'place_url': 'http://place.map.kakao.com/20705154',
#    'road_address_name': '서울 마포구 월드컵북로 22',
#    'x': '126.919993980608',
#    'y': '37.5568646370831'},
#   {'address_name': '서울 마포구 상수동 86-22',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '17127074',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 홍대삼거리점',
#    'place_url': 'http://place.map.kakao.com/17127074',
#    'road_address_name': '서울 마포구 와우산로 64',
#    'x': '126.92328058235611',
#    'y': '37.55025439607592'},
#   {'address_name': '서울 마포구 동교동 159-1',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '22105109',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 홍대역점',
#    'place_url': 'http://place.map.kakao.com/22105109',
#    'road_address_name': '서울 마포구 양화로 165',
#    'x': '126.923637798148',
#    'y': '37.5572887166274'},
#   {'address_name': '서울 마포구 상수동 329-1',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '26848996',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 상수역점',
#    'place_url': 'http://place.map.kakao.com/26848996',
#    'road_address_name': '서울 마포구 독막로 88',
#    'x': '126.923272022704',
#    'y': '37.5475649101839'},
#   {'address_name': '서울 마포구 동교동 165-1',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '1485627824',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 홍대역8번출구점',
#    'place_url': 'http://place.map.kakao.com/1485627824',
#    'road_address_name': '서울 마포구 양화로 166',
#    'x': '126.924168013515',
#    'y': '37.5567448560452'},
#   {'address_name': '서울 마포구 동교동 166-1',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '231272664',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 홍대공항철도역점',
#    'place_url': 'http://place.map.kakao.com/231272664',
#    'road_address_name': '서울 마포구 양화로 178',
#    'x': '126.92518582665798',
#    'y': '37.557509550972256'},
#   {'address_name': '서울 마포구 망원동 205-8',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '1752574662',
#    'phone': '1522-3232',
#    'place_name': '스타벅스 망원한강공원점',
#    'place_url': 'http://place.map.kakao.com/1752574662',
#    'road_address_name': '',
#    'x': '126.89591772587283',
#    'y': '37.55392483489065'},
#   {'address_name': '서울 마포구 창전동 130',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#    'distance': '',
#    'id': '1572099327',
#    'phone': '',
#    'place_name': '스타벅스 서강광흥창역점',
#    'place_url': 'http://place.map.kakao.com/1572099327',
#    'road_address_name': '서울 마포구 서강로 69',
#    'x': '126.931657893743',
#    'y': '37.5493756625598'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '스타벅스',
#    'region': ['경기 평택시 합정동'],
#    'selected_region': '서울 마포구 합정동'},
#   'total_count': 45}}

# %%
import requests

searching = '합정 스타벅스'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

headers = {
    "Authorization": "KakaoAK b37533f330aa94672bfb49ee94dc4dbf"     
    # 입력시 반드시  KakaoAK 뒤에 한 칸 띄우고 API키 값을 적어야 합니다. 
}

places = requests.get(url, headers = headers).json()['documents']
places
# Out:
# [{'address_name': '서울 마포구 서교동 395-166',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '26572121',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 서교점',
#   'place_url': 'http://place.map.kakao.com/26572121',
#   'road_address_name': '서울 마포구 양화로 78',
#   'x': '126.916980454434',
#   'y': '37.5514601750423'},
#  {'address_name': '서울 마포구 합정동 472',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '2057327896',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정점',
#   'place_url': 'http://place.map.kakao.com/2057327896',
#   'road_address_name': '서울 마포구 월드컵로1길 14',
#   'x': '126.91253700818196',
#   'y': '37.54994959743763'},
#  {'address_name': '서울 마포구 서교동 490',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '288597324',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정폴리스R점',
#   'place_url': 'http://place.map.kakao.com/288597324',
#   'road_address_name': '서울 마포구 양화로 45',
#   'x': '126.91340049045',
#   'y': '37.5508989849269'},
#  {'address_name': '서울 마포구 서교동 490',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '27076117',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정메세나몰점',
#   'place_url': 'http://place.map.kakao.com/27076117',
#   'road_address_name': '서울 마포구 양화로 45',
#   'x': '126.913541853312',
#   'y': '37.5500016943689'},
#  {'address_name': '서울 마포구 서교동 475-13',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '12776689',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 망원역점',
#   'place_url': 'http://place.map.kakao.com/12776689',
#   'road_address_name': '서울 마포구 월드컵로 74',
#   'x': '126.91071941264',
#   'y': '37.5557803955969'},
#  {'address_name': '서울 마포구 서교동 374-20',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '27416913',
#   'phone': '',
#   'place_name': '스타벅스 서교동사거리',
#   'place_url': 'http://place.map.kakao.com/27416913',
#   'road_address_name': '서울 마포구 양화로 105',
#   'x': '126.918607875358',
#   'y': '37.5534723352988'},
#  {'address_name': '서울 마포구 서교동 353-5',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1436512690',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대입구역사거리R점',
#   'place_url': 'http://place.map.kakao.com/1436512690',
#   'road_address_name': '서울 마포구 양화로 125',
#   'x': '126.920317785646',
#   'y': '37.5546231745866'},
#  {'address_name': '서울 마포구 동교동 205-6',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '20705154',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 동교점',
#   'place_url': 'http://place.map.kakao.com/20705154',
#   'road_address_name': '서울 마포구 월드컵북로 22',
#   'x': '126.919993980608',
#   'y': '37.5568646370831'},
#  {'address_name': '서울 마포구 상수동 86-22',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '17127074',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대삼거리점',
#   'place_url': 'http://place.map.kakao.com/17127074',
#   'road_address_name': '서울 마포구 와우산로 64',
#   'x': '126.92328058235611',
#   'y': '37.55025439607592'},
#  {'address_name': '서울 마포구 동교동 159-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '22105109',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대역점',
#   'place_url': 'http://place.map.kakao.com/22105109',
#   'road_address_name': '서울 마포구 양화로 165',
#   'x': '126.923637798148',
#   'y': '37.5572887166274'},
#  {'address_name': '서울 마포구 상수동 329-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '26848996',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 상수역점',
#   'place_url': 'http://place.map.kakao.com/26848996',
#   'road_address_name': '서울 마포구 독막로 88',
#   'x': '126.923272022704',
#   'y': '37.5475649101839'},
#  {'address_name': '서울 마포구 동교동 165-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1485627824',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대역8번출구점',
#   'place_url': 'http://place.map.kakao.com/1485627824',
#   'road_address_name': '서울 마포구 양화로 166',
#   'x': '126.924168013515',
#   'y': '37.5567448560452'},
#  {'address_name': '서울 마포구 동교동 166-1',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '231272664',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 홍대공항철도역점',
#   'place_url': 'http://place.map.kakao.com/231272664',
#   'road_address_name': '서울 마포구 양화로 178',
#   'x': '126.92518582665798',
#   'y': '37.557509550972256'},
#  {'address_name': '서울 마포구 망원동 205-8',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1752574662',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 망원한강공원점',
#   'place_url': 'http://place.map.kakao.com/1752574662',
#   'road_address_name': '',
#   'x': '126.89591772587283',
#   'y': '37.55392483489065'},
#  {'address_name': '서울 마포구 창전동 130',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '1572099327',
#   'phone': '',
#   'place_name': '스타벅스 서강광흥창역점',
#   'place_url': 'http://place.map.kakao.com/1572099327',
#   'road_address_name': '서울 마포구 서강로 69',
#   'x': '126.931657893743',
#   'y': '37.5493756625598'}]
